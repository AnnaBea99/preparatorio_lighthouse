# %%
import math
import datetime
import os

# %% [markdown]
# ### Módulos Nativos

# %%
# math
raiz = math.sqrt(25)
print(f"a raiz quadrada de 25 é: {raiz}")

print()

# datetime
agora = datetime.datetime.now()
print(f"data e hora atual: {agora.strftime('%d/%m/%Y %H:%M:%S')}")

print()

# OS
pasta_atual = os.getcwd()
print(f"diretorio atual: {pasta_atual}")
